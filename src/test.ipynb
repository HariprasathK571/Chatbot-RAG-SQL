# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "src")))

# %%
from chatbot.service import MSSQLConnector
from db.core import DbSession
from db.core import engine

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "src")))

# %%
conn = MSSQLConnector()

# %%
a = conn.export_schema_with_samples()

# %%
print(a)
# Out:
# -- Schema: common
#
# -- Table: common.AmountBaseSignatories
# CREATE TABLE common.[AmountBaseSignatories] (
#     [Id] INTEGER NOT NULL,
#     [Module] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [OrganizationalRoleId] INTEGER NOT NULL,
#     [EmployeeId] INTEGER,
#     [Level] INTEGER NOT NULL,
#     [MinValueFlag] BIT NOT NULL,
#     [MaxValueFlag] BIT NOT NULL,
#     [NonUser] BIT NOT NULL,
#     [MinValue] DECIMAL(18, 2),
#     [MaxValue] DECIMAL(18, 2),
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_AmountBaseSignatories] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_AmountBaseSignatories_Employees_EmployeeId] FOREIGN KEY([EmployeeId]) REFERENCES masterdata.[Employees] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_AmountBaseSignatories_OrganizationalRoles_OrganizationalRoleId] FOREIGN KEY([OrganizationalRoleId]) REFERENCES masterdata.[OrganizationalRoles] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: common.OrganizationalRolesInRoleBaseSignatories
# CREATE TABLE common.[OrganizationalRolesInRoleBaseSignatories] (
#     [Id] INTEGER NOT NULL,
#     [RoleBaseSignatoryId] INTEGER NOT NULL,
#     [OrganizationalRoleId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_OrganizationalRolesInRoleBaseSignatories] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_OrganizationalRolesInRoleBaseSignatories_OrganizationalRoles_OrganizationalRoleId] FOREIGN KEY([OrganizationalRoleId]) REFERENCES masterdata.[OrganizationalRoles] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_OrganizationalRolesInRoleBaseSignatories_RoleBaseSignatories_RoleBaseSignatoryId] FOREIGN KEY([RoleBaseSignatoryId]) REFERENCES common.[RoleBaseSignatories] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: common.RoleBaseSignatories
# CREATE TABLE common.[RoleBaseSignatories] (
#     [Id] INTEGER NOT NULL,
#     [Module] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [OrganizationalRoleId] INTEGER NOT NULL,
#     [EmployeeId] INTEGER NOT NULL,
#     [Level] INTEGER NOT NULL,
#     [AppliesToAll] BIT NOT NULL,
#     [Nonuser] BIT NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_RoleBaseSignatories] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_RoleBaseSignatories_Employees_EmployeeId] FOREIGN KEY([EmployeeId]) REFERENCES masterdata.[Employees] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_RoleBaseSignatories_OrganizationalRoles_OrganizationalRoleId] FOREIGN KEY([OrganizationalRoleId]) REFERENCES masterdata.[OrganizationalRoles] ([Id]) ON DELETE CASCADE
# );
# -- Schema: db_accessadmin
# -- Schema: db_backupoperator
# -- Schema: db_datareader
# -- Schema: db_datawriter
# -- Schema: db_ddladmin
# -- Schema: db_denydatareader
# -- Schema: db_denydatawriter
# -- Schema: db_owner
# -- Schema: db_securityadmin
# -- Schema: dbo
#
# -- Table: dbo.__EFMigrationsHistory
# CREATE TABLE dbo.[__EFMigrationsHistory] (
#     [MigrationId] NVARCHAR(150) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ProductVersion] NVARCHAR(32) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED ([MigrationId])
# );
#
# /*
# 2 rows from __EFMigrationsHistory table:
# MigrationId	ProductVersion
# 20250325122822_CommonInitialMigration	9.0.0
# 20250325124841_InventoryInitialMigration	9.0.0
# */
#
#
# -- Table: dbo.ManufacturingItemDataCollectionParameter
# CREATE TABLE dbo.[ManufacturingItemDataCollectionParameter] (
#     [Id] INTEGER NOT NULL,
#     [ManufacturingItemId] INTEGER NOT NULL,
#     [ProcessId] INTEGER NOT NULL,
#     [DataCollectionParameterId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_ManufacturingItemDataCollectionParameter] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_ManufacturingItemDataCollectionParameter_DataCollectionParameters_DataCollectionParameterId] FOREIGN KEY([DataCollectionParameterId]) REFERENCES spc.[DataCollectionParameters] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_ManufacturingItemDataCollectionParameter_ManufacturingItems_ManufacturingItemId] FOREIGN KEY([ManufacturingItemId]) REFERENCES inventory.[ManufacturingItems] ([ItemId]) ON DELETE CASCADE,
#     CONSTRAINT [FK_ManufacturingItemDataCollectionParameter_Processes_ProcessId] FOREIGN KEY([ProcessId]) REFERENCES inventory.[Processes] ([Id]) ON DELETE CASCADE
# );
# -- Schema: guest
# -- Schema: HangFire
#
# -- Table: HangFire.AggregatedCounter
# CREATE TABLE HangFire.[AggregatedCounter] (
#     [Key] NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Value] BIGINT NOT NULL,
#     [ExpireAt] DATETIME,
#     CONSTRAINT [PK_HangFire_CounterAggregated] PRIMARY KEY CLUSTERED ([Key])
# );
#
# -- Table: HangFire.Counter
# CREATE TABLE HangFire.[Counter] (
#     [Key] NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Value] INTEGER NOT NULL,
#     [ExpireAt] DATETIME,
#     [Id] BIGINT NOT NULL,
#     CONSTRAINT [PK_HangFire_Counter] PRIMARY KEY CLUSTERED ([Key], [Id])
# );
#
# -- Table: HangFire.Hash
# CREATE TABLE HangFire.[Hash] (
#     [Key] NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Field] NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Value] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [ExpireAt] DATETIME2,
#     CONSTRAINT [PK_HangFire_Hash] PRIMARY KEY CLUSTERED ([Key], [Field])
# );
#
# -- Table: HangFire.Job
# CREATE TABLE HangFire.[Job] (
#     [Id] BIGINT NOT NULL,
#     [StateId] BIGINT,
#     [StateName] NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [InvocationData] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Arguments] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [CreatedAt] DATETIME NOT NULL,
#     [ExpireAt] DATETIME,
#     CONSTRAINT [PK_HangFire_Job] PRIMARY KEY CLUSTERED ([Id])
# );
#
# -- Table: HangFire.JobParameter
# CREATE TABLE HangFire.[JobParameter] (
#     [JobId] BIGINT NOT NULL,
#     [Name] NVARCHAR(40) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Value] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     CONSTRAINT [PK_HangFire_JobParameter] PRIMARY KEY CLUSTERED ([JobId], [Name]),
#     CONSTRAINT [FK_HangFire_JobParameter_Job] FOREIGN KEY([JobId]) REFERENCES HangFire.[Job] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: HangFire.JobQueue
# CREATE TABLE HangFire.[JobQueue] (
#     [Id] BIGINT NOT NULL,
#     [JobId] BIGINT NOT NULL,
#     [Queue] NVARCHAR(50) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [FetchedAt] DATETIME,
#     CONSTRAINT [PK_HangFire_JobQueue] PRIMARY KEY CLUSTERED ([Queue], [Id])
# );
#
# -- Table: HangFire.List
# CREATE TABLE HangFire.[List] (
#     [Id] BIGINT NOT NULL,
#     [Key] NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Value] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [ExpireAt] DATETIME,
#     CONSTRAINT [PK_HangFire_List] PRIMARY KEY CLUSTERED ([Key], [Id])
# );
#
# -- Table: HangFire.Schema
# CREATE TABLE HangFire.[Schema] (
#     [Version] INTEGER NOT NULL,
#     CONSTRAINT [PK_HangFire_Schema] PRIMARY KEY CLUSTERED ([Version])
# );
#
# /*
# 1 rows from Schema table:
# Version
# 9
# */
#
#
# -- Table: HangFire.Server
# CREATE TABLE HangFire.[Server] (
#     [Id] NVARCHAR(200) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Data] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [LastHeartbeat] DATETIME NOT NULL,
#     CONSTRAINT [PK_HangFire_Server] PRIMARY KEY CLUSTERED ([Id])
# );
#
# -- Table: HangFire.Set
# CREATE TABLE HangFire.[Set] (
#     [Key] NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Score] FLOAT NOT NULL,
#     [Value] NVARCHAR(256) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ExpireAt] DATETIME,
#     CONSTRAINT [PK_HangFire_Set] PRIMARY KEY CLUSTERED ([Key], [Value])
# );
#
# -- Table: HangFire.State
# CREATE TABLE HangFire.[State] (
#     [Id] BIGINT NOT NULL,
#     [JobId] BIGINT NOT NULL,
#     [Name] NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Reason] NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [CreatedAt] DATETIME NOT NULL,
#     [Data] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     CONSTRAINT [PK_HangFire_State] PRIMARY KEY CLUSTERED ([JobId], [Id]),
#     CONSTRAINT [FK_HangFire_State_Job] FOREIGN KEY([JobId]) REFERENCES HangFire.[Job] ([Id]) ON DELETE CASCADE
# );
# -- Schema: iiot
#
# -- Table: iiot.ApiIntegrationLogs
# CREATE TABLE iiot.[ApiIntegrationLogs] (
#     [Id] INTEGER NOT NULL,
#     [LogNo] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Endpoint] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [StartDate] DATETIME2 NOT NULL,
#     [EndDate] DATETIME2 NOT NULL,
#     [TotalDuration] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Payload] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Message] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Response] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [IpAddress] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_ApiIntegrationLogs] PRIMARY KEY CLUSTERED ([Id])
# );
#
# /*
# 2 rows from ApiIntegrationLogs table:
# Id	LogNo	Endpoint	StartDate	EndDate	TotalDuration	Payload	Message	Response	IpAddress	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	0000001	/LotTravellerService/move-next-service	2025-06-20 08:21:02.217763	2025-06-20 08:21:02.919360	00:00:00.701	{
#   "serials": [
#     "200620250809550001L1A"
#   ],
#   "machines": [
#     "LM01"
#   ],
#   "operators": [
#     "kesavan"
#   ],
#   "tools": [],
#   "materials": [],
#   "dataCollections": [],
#   "transactionDateTime": "2025-06-19T10:59:49",
#   "isBatch": true,
#   "defects": [],
#   "reworksToProcess": ""
# }	Move Next Successful.	null	192.168.43.41	NULL	2025-06-20 08:21:02.217814	NULL	NULL
# 2	0000001	/LotTravellerService/move-next-service	2025-06-20 08:21:26.165965	2025-06-20 08:21:26.228066	00:00:00.062	{
#   "serials": [
#     "200620250809550001L1A"
#   ],
#   "machines": [
#     "SPP01"
#   ],
#   "operators": [
#     "kesavan"
#   ],
#   "tools": [],
#   "materials": [],
#   "dataCollections": [],
#   "transactionDateTime": "2025-06-19T10:59:49",
#   "isBatch": true,
#   "defects": [],
#   "reworksToProcess": ""
# }	Move Next Successful.	null	192.168.43.41	NULL	2025-06-20 08:21:26.165966	NULL	NULL
# */
#
#
# -- Table: iiot.IntegrationConfigurations
# CREATE TABLE iiot.[IntegrationConfigurations] (
#     [Id] INTEGER NOT NULL,
#     [Name] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Description] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [EndPointUrl] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [Port] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [IntegrationType] INTEGER NOT NULL,
#     [ModuleId] INTEGER,
#     [InboundAction] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [OutboundAction] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_IntegrationConfigurations] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_IntegrationConfigurations_Modules_ModuleId] FOREIGN KEY([ModuleId]) REFERENCES masterdata.[Modules] ([Id]) ON DELETE NO ACTION
# );
# -- Schema: INFORMATION_SCHEMA
# -- Schema: inventory
#
# -- Table: inventory.Accounts
# CREATE TABLE inventory.[Accounts] (
#     [Id] INTEGER NOT NULL,
#     [AccountType] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [AccountCode] NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [AccountDescription] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Balance] DECIMAL(18, 2) NOT NULL,
#     [Status] INTEGER NOT NULL,
#     [SubAccountOfId] INTEGER,
#     [BalanceSheetGroupId] INTEGER,
#     [IncomeStatementGroupId] INTEGER,
#     [CashFlowGroupId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_Accounts] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_Accounts_Accounts_SubAccountOfId] FOREIGN KEY([SubAccountOfId]) REFERENCES inventory.[Accounts] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Accounts_BalanceSheetGroups_BalanceSheetGroupId] FOREIGN KEY([BalanceSheetGroupId]) REFERENCES inventory.[BalanceSheetGroups] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Accounts_CashFlowGroups_CashFlowGroupId] FOREIGN KEY([CashFlowGroupId]) REFERENCES inventory.[CashFlowGroups] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Accounts_IncomeStatementGroups_IncomeStatementGroupId] FOREIGN KEY([IncomeStatementGroupId]) REFERENCES inventory.[IncomeStatementGroups] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.AlternateBillOfMaterialsItems
# CREATE TABLE inventory.[AlternateBillOfMaterialsItems] (
#     [Id] INTEGER NOT NULL,
#     [AlternateOfId] INTEGER NOT NULL,
#     [ItemId] INTEGER NOT NULL,
#     [UsageQuantityValue] FLOAT NOT NULL,
#     [UsageQuantityUnitOfMeasureCode] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [UsageQuantityUnitOfMeasureConversionFactor] FLOAT NOT NULL,
#     [BaseQuantityValue] FLOAT NOT NULL,
#     [BaseQuantityUnitOfMeasureCode] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [BaseQuantityUnitOfMeasureConversionFactor] FLOAT NOT NULL,
#     [UsageMethod] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_AlternateBillOfMaterialsItems] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_AlternateBillOfMaterialsItems_BillOfMaterialItems_AlternateOfId] FOREIGN KEY([AlternateOfId]) REFERENCES inventory.[BillOfMaterialItems] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_AlternateBillOfMaterialsItems_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.AlternateRouteOptions
# CREATE TABLE inventory.[AlternateRouteOptions] (
#     [AlternateRouteOptionId] INTEGER NOT NULL,
#     [ProductionOperationId] INTEGER NOT NULL,
#     CONSTRAINT [PK_AlternateRouteOptions] PRIMARY KEY CLUSTERED ([AlternateRouteOptionId], [ProductionOperationId]),
#     CONSTRAINT [FK_AlternateRouteOptions_ProductionOperations_AlternateRouteOptionId] FOREIGN KEY([AlternateRouteOptionId]) REFERENCES inventory.[ProductionOperations] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_AlternateRouteOptions_ProductionOperations_ProductionOperationId] FOREIGN KEY([ProductionOperationId]) REFERENCES inventory.[ProductionOperations] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: inventory.BackflushMaterialAttributes
# CREATE TABLE inventory.[BackflushMaterialAttributes] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentGroupId] INTEGER NOT NULL,
#     [DataCollectionParameterId] INTEGER NOT NULL,
#     [IsRequired] BIT NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_BackflushMaterialAttributes] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_BackflushMaterialAttributes_DataCollectionParameters_DataCollectionParameterId] FOREIGN KEY([DataCollectionParameterId]) REFERENCES spc.[DataCollectionParameters] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_BackflushMaterialAttributes_EquipmentGroups_EquipmentGroupId] FOREIGN KEY([EquipmentGroupId]) REFERENCES inventory.[EquipmentGroups] ([ItemId]) ON DELETE CASCADE
# );
#
# -- Table: inventory.BalanceSheetGroups
# CREATE TABLE inventory.[BalanceSheetGroups] (
#     [Id] INTEGER NOT NULL,
#     [Name] NVARCHAR(450) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Sequence] INTEGER NOT NULL,
#     [SubGroupOfId] INTEGER,
#     [BalanceSheetGroupType] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_BalanceSheetGroups] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_BalanceSheetGroups_BalanceSheetGroups_SubGroupOfId] FOREIGN KEY([SubGroupOfId]) REFERENCES inventory.[BalanceSheetGroups] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.BankAccounts
# CREATE TABLE inventory.[BankAccounts] (
#     [Id] INTEGER NOT NULL,
#     [BankId] INTEGER NOT NULL,
#     [BankAccountNumber] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [AccountId] INTEGER NOT NULL,
#     [Balance] DECIMAL(18, 2) NOT NULL,
#     [Date] DATETIME2 NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_BankAccounts] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_BankAccounts_Accounts_AccountId] FOREIGN KEY([AccountId]) REFERENCES inventory.[Accounts] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_BankAccounts_Banks_BankId] FOREIGN KEY([BankId]) REFERENCES inventory.[Banks] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: inventory.Banks
# CREATE TABLE inventory.[Banks] (
#     [Id] INTEGER NOT NULL,
#     [Name] NVARCHAR(450) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ShortName] NVARCHAR(450) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [IsCustomerBank] BIT NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_Banks] PRIMARY KEY CLUSTERED ([Id])
# );
#
# -- Table: inventory.BillOfMaterialItems
# CREATE TABLE inventory.[BillOfMaterialItems] (
#     [Id] INTEGER NOT NULL,
#     [BillOfMaterialId] INTEGER NOT NULL,
#     [ItemId] INTEGER NOT NULL,
#     [UsageQuantityValue] FLOAT NOT NULL,
#     [UsageQuantityUnitOfMeasureCode] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [UsageQuantityUnitOfMeasureConversionFactor] FLOAT NOT NULL,
#     [BaseQuantityValue] FLOAT NOT NULL,
#     [BaseQuantityUnitOfMeasureCode] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [BaseQuantityUnitOfMeasureConversionFactor] FLOAT NOT NULL,
#     [UsageMethod] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_BillOfMaterialItems] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_BillOfMaterialItems_BillOfMaterials_BillOfMaterialId] FOREIGN KEY([BillOfMaterialId]) REFERENCES inventory.[BillOfMaterials] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_BillOfMaterialItems_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE CASCADE
# );
#
# /*
# 2 rows from BillOfMaterialItems table:
# Id	BillOfMaterialId	ItemId	UsageQuantityValue	UsageQuantityUnitOfMeasureCode	UsageQuantityUnitOfMeasureConversionFactor	BaseQuantityValue	BaseQuantityUnitOfMeasureCode	BaseQuantityUnitOfMeasureConversionFactor	UsageMethod	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	1	5	1.0	PC	1.0	1.0	PC	1.0	2	NULL	2025-03-25 21:22:16.242753	NULL	NULL
# 2	3	5	1.0	PC	1.0	1.0	PC	1.0	1	NULL	2025-05-26 16:29:18.225386	NULL	NULL
# */
#
#
# -- Table: inventory.BillOfMaterials
# CREATE TABLE inventory.[BillOfMaterials] (
#     [Id] INTEGER NOT NULL,
#     [Code] NVARCHAR(200) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Description] NVARCHAR(1000) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ItemId] INTEGER NOT NULL,
#     [Remarks] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [AlternateBOM] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [BillOfMaterialsItemId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     [RevisionName] NVARCHAR(20) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [State] INTEGER NOT NULL,
#     [ReleaseLogUserId] INTEGER,
#     [ReleaseLogDateTime] DATETIME2,
#     [ArchiveLogUserId] INTEGER,
#     [ArchiveLogDateTime] DATETIME2,
#     CONSTRAINT [PK_BillOfMaterials] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_BillOfMaterials_BillOfMaterialItems_BillOfMaterialsItemId] FOREIGN KEY([BillOfMaterialsItemId]) REFERENCES inventory.[BillOfMaterialItems] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_BillOfMaterials_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_BillOfMaterials_Users_ArchiveLogUserId] FOREIGN KEY([ArchiveLogUserId]) REFERENCES masterdata.[Users] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_BillOfMaterials_Users_ReleaseLogUserId] FOREIGN KEY([ReleaseLogUserId]) REFERENCES masterdata.[Users] ([Id]) ON DELETE NO ACTION
# );
#
# /*
# 2 rows from BillOfMaterials table:
# Id	Code	Description	ItemId	Remarks	AlternateBOM	BillOfMaterialsItemId	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate	RevisionName	State	ReleaseLogUserId	ReleaseLogDateTime	ArchiveLogUserId	ArchiveLogDateTime
# 1	PPFGI	Packed Process Finished Good Bill Of Material	6	Packed Process Finished Good Bill Of Material		NULL	NULL	2025-03-25 21:22:16.265876	NULL	NULL	Revision 0	10	NULL	2025-03-25 21:22:55.477818	NULL	NULL
# 2	PPFGIB	Packed Process Finished Good Bill Of Material Batch	7			NULL	NULL	2025-04-24 11:39:28.077769	NULL	NULL	Revision 0	10	NULL	2025-04-24 11:39:51.478751	NULL	NULL
# */
#
#
# -- Table: inventory.BinningSpecDetails
# CREATE TABLE inventory.[BinningSpecDetails] (
#     [Id] INTEGER NOT NULL,
#     [BinningSpecId] INTEGER,
#     [CoProductByProductId] INTEGER,
#     [ConsumptionPercentage] DECIMAL(19, 5),
#     [LocationId] INTEGER,
#     [CommonProductSpecId] INTEGER,
#     [ProductionOperationId] INTEGER,
#     [DefectId] INTEGER,
#     [ReworkReasonCodeId] INTEGER,
#     [FailActionType] INTEGER,
#     [SplitToNewLot] BIT,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_BinningSpecDetails] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_BinningSpecDetails_BinningSpecs_BinningSpecId] FOREIGN KEY([BinningSpecId]) REFERENCES inventory.[BinningSpecs] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_BinningSpecDetails_Defects_DefectId] FOREIGN KEY([DefectId]) REFERENCES inventory.[Defects] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_BinningSpecDetails_Items_CoProductByProductId] FOREIGN KEY([CoProductByProductId]) REFERENCES inventory.[Items] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_BinningSpecDetails_Locations_LocationId] FOREIGN KEY([LocationId]) REFERENCES inventory.[Locations] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_BinningSpecDetails_ProductionOperations_ProductionOperationId] FOREIGN KEY([ProductionOperationId]) REFERENCES inventory.[ProductionOperations] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_BinningSpecDetails_ProductSpecs_CommonProductSpecId] FOREIGN KEY([CommonProductSpecId]) REFERENCES inventory.[ProductSpecs] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_BinningSpecDetails_ReworkReasonCodes_ReworkReasonCodeId] FOREIGN KEY([ReworkReasonCodeId]) REFERENCES inventory.[ReworkReasonCodes] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.BinningSpecs
# CREATE TABLE inventory.[BinningSpecs] (
#     [Id] INTEGER NOT NULL,
#     [Code] NVARCHAR(100) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [Description] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [SplitToNewLot] BIT,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_BinningSpecs] PRIMARY KEY CLUSTERED ([Id])
# );
#
# -- Table: inventory.BomMappingEquipmentFeeders
# CREATE TABLE inventory.[BomMappingEquipmentFeeders] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentFeederId] INTEGER NOT NULL,
#     [BomMappingId] INTEGER NOT NULL,
#     [BillOfMaterialsId] INTEGER NOT NULL,
#     [NoOfCarrier] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_BomMappingEquipmentFeeders] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_BomMappingEquipmentFeeders_BillOfMaterials_BillOfMaterialsId] FOREIGN KEY([BillOfMaterialsId]) REFERENCES inventory.[BillOfMaterials] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_BomMappingEquipmentFeeders_BomMappings_BomMappingId] FOREIGN KEY([BomMappingId]) REFERENCES inventory.[BomMappings] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_BomMappingEquipmentFeeders_EquipmentFeeders_EquipmentFeederId] FOREIGN KEY([EquipmentFeederId]) REFERENCES inventory.[EquipmentFeeders] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.BomMappings
# CREATE TABLE inventory.[BomMappings] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentId] INTEGER NOT NULL,
#     [ItemId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_BomMappings] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_BomMappings_Equipment_EquipmentId] FOREIGN KEY([EquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_BomMappings_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: inventory.CashFlowGroups
# CREATE TABLE inventory.[CashFlowGroups] (
#     [Id] INTEGER NOT NULL,
#     [CashFlowCategory] INTEGER NOT NULL,
#     [Name] NVARCHAR(450) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Sequence] INTEGER NOT NULL,
#     [SubGroupOfId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_CashFlowGroups] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_CashFlowGroups_CashFlowGroups_SubGroupOfId] FOREIGN KEY([SubGroupOfId]) REFERENCES inventory.[CashFlowGroups] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.CementHouse
# CREATE TABLE inventory.[CementHouse] (
#     [Id] INTEGER NOT NULL,
#     [ProductCodeId] INTEGER NOT NULL,
#     [CarrierId] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [DomShift] DATETIME2 NOT NULL,
#     [ShiftDomId] INTEGER NOT NULL,
#     [DoeShift] DATETIME2 NOT NULL,
#     [ShiftDoeId] INTEGER NOT NULL,
#     [FillingDateTime] DATETIME2 NOT NULL,
#     [Quantity] INTEGER NOT NULL,
#     [TrackingNumber] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [OperatorId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_CementHouse] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_CementHouse_Items_ProductCodeId] FOREIGN KEY([ProductCodeId]) REFERENCES inventory.[Items] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_CementHouse_Operators_OperatorId] FOREIGN KEY([OperatorId]) REFERENCES inventory.[Operators] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_CementHouse_Shifts_ShiftDoeId] FOREIGN KEY([ShiftDoeId]) REFERENCES inventory.[Shifts] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_CementHouse_Shifts_ShiftDomId] FOREIGN KEY([ShiftDomId]) REFERENCES inventory.[Shifts] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.ChangeOrderReasonCode
# CREATE TABLE inventory.[ChangeOrderReasonCode] (
#     [Id] INTEGER NOT NULL,
#     [Code] NVARCHAR(40) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Description] NVARCHAR(2000) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_ChangeOrderReasonCode] PRIMARY KEY CLUSTERED ([Id])
# );
#
# -- Table: inventory.Cleanings
# CREATE TABLE inventory.[Cleanings] (
#     [Id] INTEGER NOT NULL,
#     [ItemId] INTEGER NOT NULL,
#     [BasketId] INTEGER NOT NULL,
#     [Tray] INTEGER NOT NULL,
#     [SerialNumber] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [BatchNumber] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [BatchQuantity] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_Cleanings] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_Cleanings_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Cleanings_Tools_BasketId] FOREIGN KEY([BasketId]) REFERENCES inventory.[Tools] ([Id]) ON DELETE CASCADE
# );
#
# /*
# 2 rows from Cleanings table:
# Id	ItemId	BasketId	Tray	SerialNumber	BatchNumber	BatchQuantity	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	1	1	0	NULL	3	23	NULL	2025-06-09 15:11:41.638100	NULL	NULL
# 2	1	1	0	NULL	1	10	NULL	2025-06-09 15:17:52.695668	NULL	NULL
# */
#
#
# -- Table: inventory.ContainerMonitorings
# CREATE TABLE inventory.[ContainerMonitorings] (
#     [Id] INTEGER NOT NULL,
#     [ContainerSpecId] INTEGER NOT NULL,
#     [Status] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_ContainerMonitorings] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_ContainerMonitorings_ContainerSpecs_ContainerSpecId] FOREIGN KEY([ContainerSpecId]) REFERENCES inventory.[ContainerSpecs] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: inventory.ContainerSpecItems
# CREATE TABLE inventory.[ContainerSpecItems] (
#     [Id] INTEGER NOT NULL,
#     [ContainerSpecId] INTEGER NOT NULL,
#     [ItemId] INTEGER NOT NULL,
#     [MaximumQuantity] INTEGER NOT NULL,
#     [NetWeight] FLOAT,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_ContainerSpecItems] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_ContainerSpecItems_ContainerSpecs_ContainerSpecId] FOREIGN KEY([ContainerSpecId]) REFERENCES inventory.[ContainerSpecs] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_ContainerSpecItems_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.ContainerSpecs
# CREATE TABLE inventory.[ContainerSpecs] (
#     [Id] INTEGER NOT NULL,
#     [ItemSubCategoryId] INTEGER NOT NULL,
#     [ItemId] INTEGER NOT NULL,
#     [Description] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ContainerMonitoringId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_ContainerSpecs] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_ContainerSpecs_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.ControlNumberSettings
# CREATE TABLE inventory.[ControlNumberSettings] (
#     [Id] INTEGER NOT NULL,
#     [Module] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [Format] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [Counter] BIGINT,
#     [AlphanumericCounter] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [LastAlphanumericCounter] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_ControlNumberSettings] PRIMARY KEY CLUSTERED ([Id])
# );
#
# /*
# 2 rows from ControlNumberSettings table:
# Id	Module	Format	Counter	AlphanumericCounter	LastAlphanumericCounter	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	AP Voucher	{series}	1	NULL	NULL	NULL	NULL	NULL	NULL
# 2	Disbursement Voucher	{series}	1	NULL	NULL	NULL	NULL	NULL	NULL
# */
#
#
# -- Table: inventory.Customers
# CREATE TABLE inventory.[Customers] (
#     [Id] INTEGER NOT NULL,
#     [CustomerName] NVARCHAR(120) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [CustomerCode] NVARCHAR(120) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [BusinessPartnerType] INTEGER,
#     [CreditLimit] DECIMAL(12, 2) NOT NULL,
#     [Address] NVARCHAR(510) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [EmailAddress] NVARCHAR(120) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [ContactNumber] NVARCHAR(120) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [FaxNumber] NVARCHAR(120) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [LineOfBusiness] NVARCHAR(120) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [TinNumber] NVARCHAR(40) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [SecNumber] NVARCHAR(40) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [ContactPerson] NVARCHAR(40) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [ContactPersonPosition] NVARCHAR(40) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [OutstandingSalesOrder] DECIMAL(12, 2),
#     [Remarks] NVARCHAR(4000) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [IsActive] BIT,
#     [CurrencyId] INTEGER NOT NULL,
#     [PaymentTermId] INTEGER NOT NULL,
#     [MotherCustomerId] INTEGER,
#     [SalesPersonId] INTEGER,
#     [CollectorId] INTEGER,
#     [Vatability] INTEGER NOT NULL,
#     [TransportTime] INTEGER NOT NULL,
#     [Website] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_Customers] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_Customers_Currencies_CurrencyId] FOREIGN KEY([CurrencyId]) REFERENCES masterdata.[Currencies] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_Customers_Customers_MotherCustomerId] FOREIGN KEY([MotherCustomerId]) REFERENCES inventory.[Customers] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Customers_Employees_CollectorId] FOREIGN KEY([CollectorId]) REFERENCES masterdata.[Employees] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Customers_PaymentTerms_PaymentTermId] FOREIGN KEY([PaymentTermId]) REFERENCES inventory.[PaymentTerms] ([Id]) ON DELETE CASCADE
# );
#
# /*
# 1 rows from Customers table:
# Id	CustomerName	CustomerCode	BusinessPartnerType	CreditLimit	Address	EmailAddress	ContactNumber	FaxNumber	LineOfBusiness	TinNumber	SecNumber	ContactPerson	ContactPersonPosition	OutstandingSalesOrder	Remarks	IsActive	CurrencyId	PaymentTermId	MotherCustomerId	SalesPersonId	CollectorId	Vatability	TransportTime	Website	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	Acme Corporation	ACME-001	NULL	50000.00	NULL	NULL	NULL	NULL	NULL	NULL	NULL	NULL	NULL	NULL	NULL	True	1	1	NULL	NULL	NULL	1	3	NULL	7	2025-06-03 10:26:04.464039	7	2025-06-03 10:26:04.464039
# */
#
#
# -- Table: inventory.Cuts
# CREATE TABLE inventory.[Cuts] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentId] INTEGER NOT NULL,
#     [ItemId] INTEGER,
#     [WindupStation] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [NoOfCut] INTEGER,
#     [NoOfRoll] INTEGER,
#     [Meter] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_Cuts] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_Cuts_Equipment_EquipmentId] FOREIGN KEY([EquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_Cuts_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.DefectGroupLists
# CREATE TABLE inventory.[DefectGroupLists] (
#     [Id] INTEGER NOT NULL,
#     [DefectGroupId] INTEGER NOT NULL,
#     [DefectId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DefectGroupLists] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DefectGroupLists_DefectGroups_DefectGroupId] FOREIGN KEY([DefectGroupId]) REFERENCES inventory.[DefectGroups] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DefectGroupLists_Defects_DefectId] FOREIGN KEY([DefectId]) REFERENCES inventory.[Defects] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.DefectGroups
# CREATE TABLE inventory.[DefectGroups] (
#     [Id] INTEGER NOT NULL,
#     [Code] NVARCHAR(250) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Remarks] NVARCHAR(1000) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DefectGroups] PRIMARY KEY CLUSTERED ([Id])
# );
#
# -- Table: inventory.DefectProcesses
# CREATE TABLE inventory.[DefectProcesses] (
#     [Id] INTEGER NOT NULL,
#     [ProcessId] INTEGER NOT NULL,
#     [DefectId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DefectProcesses] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DefectProcesses_Defects_DefectId] FOREIGN KEY([DefectId]) REFERENCES inventory.[Defects] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DefectProcesses_Processes_ProcessId] FOREIGN KEY([ProcessId]) REFERENCES inventory.[Processes] ([Id]) ON DELETE CASCADE
# );
#
# /*
# 2 rows from DefectProcesses table:
# Id	ProcessId	DefectId	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 11	8	3	NULL	2025-06-24 14:05:42.120998	NULL	NULL
# 12	9	3	NULL	2025-06-24 14:05:42.121064	NULL	NULL
# */
#
#
# -- Table: inventory.Defects
# CREATE TABLE inventory.[Defects] (
#     [Id] INTEGER NOT NULL,
#     [Code] NVARCHAR(60) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Name] NVARCHAR(60) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [IsReworkable] BIT NOT NULL,
#     [CostProfitCenterId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_Defects] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_Defects_CostProfitCenters_CostProfitCenterId] FOREIGN KEY([CostProfitCenterId]) REFERENCES masterdata.[CostProfitCenters] ([Id]) ON DELETE NO ACTION
# );
#
# /*
# 2 rows from Defects table:
# Id	Code	Name	IsReworkable	CostProfitCenterId	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	SD	Scrap Defect	True	NULL	NULL	2025-04-25 06:20:06.437511	NULL	NULL
# 2	RD	Rework Defect	True	NULL	NULL	2025-04-25 06:20:15.385113	NULL	NULL
# */
#
#
# -- Table: inventory.DefectWorkCenters
# CREATE TABLE inventory.[DefectWorkCenters] (
#     [Id] INTEGER NOT NULL,
#     [WorkCenterId] INTEGER NOT NULL,
#     [DefectId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DefectWorkCenters] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DefectWorkCenters_Defects_DefectId] FOREIGN KEY([DefectId]) REFERENCES inventory.[Defects] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DefectWorkCenters_WorkCenters_WorkCenterId] FOREIGN KEY([WorkCenterId]) REFERENCES inventory.[WorkCenters] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: inventory.Designations
# CREATE TABLE inventory.[Designations] (
#     [Id] INTEGER NOT NULL,
#     [DesignationName] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_Designations] PRIMARY KEY CLUSTERED ([Id])
# );
#
# -- Table: inventory.Equipment
# CREATE TABLE inventory.[Equipment] (
#     [Id] INTEGER NOT NULL,
#     [TrackingNumber] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ItemId] INTEGER NOT NULL,
#     [EffectivityDate] DATETIME2,
#     [Efficiency] FLOAT,
#     [EquipmentGroupId] INTEGER NOT NULL,
#     [ProductionLineId] INTEGER,
#     [ParentEquipmentId] INTEGER,
#     [PrimaryEquipmentId] INTEGER,
#     [EquipmentPriorityId] INTEGER,
#     [EquipmentStatusId] INTEGER NOT NULL,
#     [CustomPropertyValuesJsonString] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [MaximumComponentLimit] INTEGER NOT NULL,
#     [HasSubMachine] BIT NOT NULL,
#     [IpAddress] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [Port] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [EquipmentMode] INTEGER NOT NULL,
#     [EquipmentGroupItemId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     [CustomPropertyValues] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     CONSTRAINT [PK_Equipment] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_Equipment_Equipment_ParentEquipmentId] FOREIGN KEY([ParentEquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Equipment_Equipment_PrimaryEquipmentId] FOREIGN KEY([PrimaryEquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Equipment_EquipmentGroups_EquipmentGroupId] FOREIGN KEY([EquipmentGroupId]) REFERENCES inventory.[EquipmentGroups] ([ItemId]) ON DELETE CASCADE,
#     CONSTRAINT [FK_Equipment_EquipmentGroups_EquipmentGroupItemId] FOREIGN KEY([EquipmentGroupItemId]) REFERENCES inventory.[EquipmentGroups] ([ItemId]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Equipment_EquipmentPriorities_EquipmentPriorityId] FOREIGN KEY([EquipmentPriorityId]) REFERENCES inventory.[EquipmentPriorities] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Equipment_EquipmentStatuses_EquipmentStatusId] FOREIGN KEY([EquipmentStatusId]) REFERENCES inventory.[EquipmentStatuses] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Equipment_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_Equipment_ProductionLines_ProductionLineId] FOREIGN KEY([ProductionLineId]) REFERENCES inventory.[ProductionLines] ([Id]) ON DELETE NO ACTION
# );
#
# /*
# 2 rows from Equipment table:
# Id	TrackingNumber	ItemId	EffectivityDate	Efficiency	EquipmentGroupId	ProductionLineId	ParentEquipmentId	PrimaryEquipmentId	EquipmentPriorityId	EquipmentStatusId	CustomPropertyValuesJsonString	MaximumComponentLimit	HasSubMachine	IpAddress	Port	EquipmentMode	EquipmentGroupItemId	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate	CustomPropertyValues
# 1	PPE000001	3	2025-03-24 16:00:00	100.0	3	1	NULL	NULL	NULL	2	NULL	1	False	NULL	NULL	0	NULL	NULL	2025-03-25 21:17:31.573233	NULL	NULL	NULL
# 2	PPE000002	4	2025-03-24 16:00:00	100.0	4	1	NULL	NULL	NULL	2	NULL	1	False	NULL	NULL	0	NULL	NULL	2025-03-25 21:17:48.474983	NULL	NULL	NULL
# */
#
#
# -- Table: inventory.EquipmentActivityLogs
# CREATE TABLE inventory.[EquipmentActivityLogs] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentActivityLogNumber] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [EquipmentStatusId] INTEGER NOT NULL,
#     [EquipmentId] INTEGER NOT NULL,
#     [WorkOrderId] INTEGER,
#     [StartDateTime] DATETIME2 NOT NULL,
#     [EndDateTime] DATETIME2,
#     [EmployeeId] INTEGER NOT NULL,
#     [Remarks] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [IsActive] BIT NOT NULL,
#     [IsImmutable] BIT,
#     [CreationLogUserId] INTEGER,
#     [CreationLogDateTime] DATETIME2,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_EquipmentActivityLogs] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_EquipmentActivityLogs_Employees_EmployeeId] FOREIGN KEY([EmployeeId]) REFERENCES masterdata.[Employees] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_EquipmentActivityLogs_Equipment_EquipmentId] FOREIGN KEY([EquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_EquipmentActivityLogs_EquipmentStatuses_EquipmentStatusId] FOREIGN KEY([EquipmentStatusId]) REFERENCES inventory.[EquipmentStatuses] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_EquipmentActivityLogs_Users_CreationLogUserId] FOREIGN KEY([CreationLogUserId]) REFERENCES masterdata.[Users] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_EquipmentActivityLogs_WorkOrders_WorkOrderId] FOREIGN KEY([WorkOrderId]) REFERENCES inventory.[WorkOrders] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.EquipmentCycleLogs
# CREATE TABLE inventory.[EquipmentCycleLogs] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentId] INTEGER NOT NULL,
#     [ShiftId] INTEGER NOT NULL,
#     [CreationDateTime] DATETIME2 NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_EquipmentCycleLogs] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_EquipmentCycleLogs_Equipment_EquipmentId] FOREIGN KEY([EquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_EquipmentCycleLogs_Shifts_ShiftId] FOREIGN KEY([ShiftId]) REFERENCES inventory.[Shifts] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: inventory.EquipmentDataCollectionParameterSets
# CREATE TABLE inventory.[EquipmentDataCollectionParameterSets] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentId] INTEGER NOT NULL,
#     [DataCollectionParameterSetId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_EquipmentDataCollectionParameterSets] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_EquipmentDataCollectionParameterSets_DataCollectionParameterSets_DataCollectionParameterSetId] FOREIGN KEY([DataCollectionParameterSetId]) REFERENCES spc.[DataCollectionParameterSets] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_EquipmentDataCollectionParameterSets_Equipment_EquipmentId] FOREIGN KEY([EquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: inventory.EquipmentDataCollections
# CREATE TABLE inventory.[EquipmentDataCollections] (
#     [Id] INTEGER NOT NULL,
#     [DataCollectionId] INTEGER NOT NULL,
#     [EquipmentId] INTEGER,
#     [EquipmentGroupId] INTEGER,
#     [EquipmentParameterSetId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_EquipmentDataCollections] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_EquipmentDataCollections_Equipment_EquipmentId] FOREIGN KEY([EquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_EquipmentDataCollections_EquipmentGroups_EquipmentGroupId] FOREIGN KEY([EquipmentGroupId]) REFERENCES inventory.[EquipmentGroups] ([ItemId]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_EquipmentDataCollections_EquipmentParameterSets_EquipmentParameterSetId] FOREIGN KEY([EquipmentParameterSetId]) REFERENCES inventory.[EquipmentParameterSets] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: inventory.EquipmentDesignations
# CREATE TABLE inventory.[EquipmentDesignations] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentId] INTEGER NOT NULL,
#     [DesignationId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_EquipmentDesignations] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_EquipmentDesignations_Designations_DesignationId] FOREIGN KEY([DesignationId]) REFERENCES inventory.[Designations] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_EquipmentDesignations_Equipment_EquipmentId] FOREIGN KEY([EquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: inventory.EquipmentFeeders
# CREATE TABLE inventory.[EquipmentFeeders] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentId] INTEGER NOT NULL,
#     [FeederId] INTEGER NOT NULL,
#     [Capacity] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_EquipmentFeeders] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_EquipmentFeeders_Equipment_EquipmentId] FOREIGN KEY([EquipmentId]) REFERENCES inventory.[Equipment] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_EquipmentFeeders_Feeders_FeederId] FOREIGN KEY([FeederId]) REFERENCES inventory.[Feeders] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: inventory.EquipmentGroupManufacturableItemSubcategories
# CREATE TABLE inventory.[EquipmentGroupManufacturableItemSubcategories] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentGroupId] INTEGER NOT NULL,
#     [ItemSubCategoryId] INTEGER NOT NULL,
#     [ComponentEquipmentGroupId] INTEGER NOT NULL,
#     [Quantity] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_EquipmentGroupManufacturableItemSubcategories] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_EquipmentGroupManufacturableItemSubcategories_EquipmentGroups_ComponentEquipmentGroupId] FOREIGN KEY([ComponentEquipmentGroupId]) REFERENCES inventory.[EquipmentGroups] ([ItemId]) ON DELETE CASCADE,
#     CONSTRAINT [FK_EquipmentGroupManufacturableItemSubcategories_EquipmentGroups_EquipmentGroupId] FOREIGN KEY([EquipmentGroupId]) REFERENCES inventory.[EquipmentGroups] ([ItemId]) ON DELETE NO ACTION,
# ...
#     CONSTRAINT [FK_DataCollectionAttributeStringValues_DataCollections_DataCollectionId] FOREIGN KEY([DataCollectionId]) REFERENCES spc.[DataCollections] ([Id]) ON DELETE CASCADE
# );
#
# /*
# 2 rows from DataCollectionAttributeStringValues table:
# Id	DataCollectionId	DataCollectionParameterId	Value	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	6	4	WOW	NULL	2025-03-26 06:07:22.859829	NULL	NULL
# 2	7	4	test	NULL	2025-04-25 03:57:34.251737	NULL	NULL
# */
#
#
# -- Table: spc.DataCollectionItems
# CREATE TABLE spc.[DataCollectionItems] (
#     [Id] INTEGER NOT NULL,
#     [DataCollectionParameterSetId] INTEGER NOT NULL,
#     [ItemId] INTEGER NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DataCollectionItems] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollectionItems_DataCollectionParameterSets_DataCollectionParameterSetId] FOREIGN KEY([DataCollectionParameterSetId]) REFERENCES spc.[DataCollectionParameterSets] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DataCollectionItems_Items_ItemId] FOREIGN KEY([ItemId]) REFERENCES inventory.[Items] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: spc.DataCollectionMeasureRules
# CREATE TABLE spc.[DataCollectionMeasureRules] (
#     [Id] INTEGER NOT NULL,
#     [DataCollectionMeasureId] INTEGER NOT NULL,
#     [StatisticType] INTEGER NOT NULL,
#     [HasSpecLimit] BIT NOT NULL,
#     [HasControlLimit] BIT NOT NULL,
#     [IsAsymmetrical] BIT NOT NULL,
#     [UpperSpecLimit] FLOAT,
#     [LowerSpecLimit] FLOAT,
#     [UpperControlLimit] FLOAT,
#     [LowerControlLimit] FLOAT,
#     [TargetMean] FLOAT NOT NULL,
#     [TargetCpk] FLOAT NOT NULL,
#     [IsTestOneActive] BIT NOT NULL,
#     [IsTestTwoActive] BIT NOT NULL,
#     [IsTestThreeActive] BIT NOT NULL,
#     [IsTestFourActive] BIT NOT NULL,
#     [IsTrendTestActive] BIT NOT NULL,
#     [IsOutOfSpecTestActive] BIT NOT NULL,
#     [EffectivityDateTime] DATETIME2,
#     [Condition] INTEGER,
#     [ConditionValue] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [ConditionValueTo] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [EquipmentStatusId] INTEGER,
#     [ConditionCounter] INTEGER,
#     [ConditionStatus] BIT,
#     [ConditionCurrentCount] INTEGER,
#     [ConditionEffectivityDateTime] DATETIME2,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DataCollectionMeasureRules] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollectionMeasureRules_DataCollectionMeasures_DataCollectionMeasureId] FOREIGN KEY([DataCollectionMeasureId]) REFERENCES spc.[DataCollectionMeasures] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DataCollectionMeasureRules_EquipmentStatuses_EquipmentStatusId] FOREIGN KEY([EquipmentStatusId]) REFERENCES inventory.[EquipmentStatuses] ([Id]) ON DELETE NO ACTION
# );
#
# /*
# 2 rows from DataCollectionMeasureRules table:
# Id	DataCollectionMeasureId	StatisticType	HasSpecLimit	HasControlLimit	IsAsymmetrical	UpperSpecLimit	LowerSpecLimit	UpperControlLimit	LowerControlLimit	TargetMean	TargetCpk	IsTestOneActive	IsTestTwoActive	IsTestThreeActive	IsTestFourActive	IsTrendTestActive	IsOutOfSpecTestActive	EffectivityDateTime	Condition	ConditionValue	ConditionValueTo	EquipmentStatusId	ConditionCounter	ConditionStatus	ConditionCurrentCount	ConditionEffectivityDateTime	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 2	6	30	True	True	False	100.0	20.0	100.0	20.0	25.0	0.0	True	True	False	False	True	False	2025-03-25 13:24:52	0	NULL	NULL	NULL	0	False	0	NULL	NULL	2025-03-25 21:31:01.054100	NULL	NULL
# 6	10	10	False	True	False	NULL	NULL	15.15	14.65	14.9	0.0	False	False	False	False	True	False	2025-06-24 08:18:24	0	NULL	NULL	NULL	0	False	0	NULL	NULL	2025-06-24 14:24:02.347029	NULL	NULL
# */
#
#
# -- Table: spc.DataCollectionMeasureRuleScopes
# CREATE TABLE spc.[DataCollectionMeasureRuleScopes] (
#     [Id] INTEGER NOT NULL,
#     [DataCollectionMeasureRuleId] INTEGER NOT NULL,
#     [DataCollectionParameterId] INTEGER NOT NULL,
#     [Value] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DataCollectionMeasureRuleScopes] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollectionMeasureRuleScopes_DataCollectionMeasureRules_DataCollectionMeasureRuleId] FOREIGN KEY([DataCollectionMeasureRuleId]) REFERENCES spc.[DataCollectionMeasureRules] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DataCollectionMeasureRuleScopes_DataCollectionParameters_DataCollectionParameterId] FOREIGN KEY([DataCollectionParameterId]) REFERENCES spc.[DataCollectionParameters] ([Id]) ON DELETE NO ACTION
# );
#
# -- Table: spc.DataCollectionMeasures
# CREATE TABLE spc.[DataCollectionMeasures] (
#     [Id] INTEGER NOT NULL,
#     [DataCollectionParameterSetId] INTEGER NOT NULL,
#     [DataCollectionParameterId] INTEGER NOT NULL,
#     [EquipmentGroupPartId] INTEGER,
#     [Formula] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [CommaSeparatedReferenceParameterCodes] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [Sequence] FLOAT NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DataCollectionMeasures] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollectionMeasures_DataCollectionParameters_DataCollectionParameterId] FOREIGN KEY([DataCollectionParameterId]) REFERENCES spc.[DataCollectionParameters] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DataCollectionMeasures_DataCollectionParameterSets_DataCollectionParameterSetId] FOREIGN KEY([DataCollectionParameterSetId]) REFERENCES spc.[DataCollectionParameterSets] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DataCollectionMeasures_EquipmentGroupParts_EquipmentGroupPartId] FOREIGN KEY([EquipmentGroupPartId]) REFERENCES inventory.[EquipmentGroupParts] ([Id]) ON DELETE NO ACTION
# );
#
# /*
# 2 rows from DataCollectionMeasures table:
# Id	DataCollectionParameterSetId	DataCollectionParameterId	EquipmentGroupPartId	Formula	CommaSeparatedReferenceParameterCodes	Sequence	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 4	1	1	NULL	NULL		10.0	NULL	2025-03-25 21:31:01.054090	NULL	NULL
# 5	1	2	NULL	NULL		20.0	NULL	2025-03-25 21:31:01.054098	NULL	NULL
# */
#
#
# -- Table: spc.DataCollectionMeasureValues
# CREATE TABLE spc.[DataCollectionMeasureValues] (
#     [Id] INTEGER NOT NULL,
#     [DataCollectionId] INTEGER NOT NULL,
#     [DataCollectionParameterId] INTEGER NOT NULL,
#     [Value] FLOAT NOT NULL,
#     [Formula] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [CommaSeparatedReferenceParameterCodes] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [EquipmentGroupPartId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DataCollectionMeasureValues] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollectionMeasureValues_DataCollectionParameters_DataCollectionParameterId] FOREIGN KEY([DataCollectionParameterId]) REFERENCES spc.[DataCollectionParameters] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DataCollectionMeasureValues_DataCollections_DataCollectionId] FOREIGN KEY([DataCollectionId]) REFERENCES spc.[DataCollections] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_DataCollectionMeasureValues_EquipmentGroupParts_EquipmentGroupPartId] FOREIGN KEY([EquipmentGroupPartId]) REFERENCES inventory.[EquipmentGroupParts] ([Id]) ON DELETE NO ACTION
# );
#
# /*
# 2 rows from DataCollectionMeasureValues table:
# Id	DataCollectionId	DataCollectionParameterId	Value	Formula	CommaSeparatedReferenceParameterCodes	EquipmentGroupPartId	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	1	1	25.0	NULL		NULL	NULL	2025-03-25 21:32:03.892540	NULL	NULL
# 2	1	2	35.0	NULL		NULL	NULL	2025-03-25 21:32:03.892856	NULL	NULL
# */
#
#
# -- Table: spc.DataCollectionParameterNumericLookupValues
# CREATE TABLE spc.[DataCollectionParameterNumericLookupValues] (
#     [Id] INTEGER NOT NULL,
#     [DataCollectionParameterId] INTEGER NOT NULL,
#     [LowerLimit] FLOAT NOT NULL,
#     [Value] FLOAT NOT NULL,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DataCollectionParameterNumericLookupValues] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollectionParameterNumericLookupValues_DataCollectionParameters_DataCollectionParameterId] FOREIGN KEY([DataCollectionParameterId]) REFERENCES spc.[DataCollectionParameters] ([Id]) ON DELETE CASCADE
# );
#
# -- Table: spc.DataCollectionParameters
# CREATE TABLE spc.[DataCollectionParameters] (
#     [Id] INTEGER NOT NULL,
#     [Code] NVARCHAR(60) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Name] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ParameterType] INTEGER NOT NULL,
#     [IsImmutable] BIT NOT NULL,
#     [ReferenceParameterId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DataCollectionParameters] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollectionParameters_DataCollectionParameters_ReferenceParameterId] FOREIGN KEY([ReferenceParameterId]) REFERENCES spc.[DataCollectionParameters] ([Id]) ON DELETE NO ACTION
# );
#
# /*
# 2 rows from DataCollectionParameters table:
# Id	Code	Name	ParameterType	IsImmutable	ReferenceParameterId	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	WGHT	Weight	10	False	NULL	NULL	2025-03-25 21:23:33.076583	NULL	NULL
# 2	WDTH	Width	10	False	NULL	NULL	2025-03-25 21:23:39.820897	NULL	NULL
# */
#
#
# -- Table: spc.DataCollectionParameterSets
# CREATE TABLE spc.[DataCollectionParameterSets] (
#     [Id] INTEGER NOT NULL,
#     [EquipmentParameterSetDataSource] INTEGER NOT NULL,
#     [Code] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Description] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [SampleSize] INTEGER NOT NULL,
#     [AllowHoldLot] BIT NOT NULL,
#     [AllowMove] BIT NOT NULL,
#     [EnableEditing] BIT NOT NULL,
#     [ExecutableFilePath] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [HasChildDataCollectionParameterSet] BIT NOT NULL,
#     [DataCollectionParameterSetId] INTEGER,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     [IsReading] BIT NOT NULL,
#     CONSTRAINT [PK_DataCollectionParameterSets] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollectionParameterSets_DataCollectionParameterSets_DataCollectionParameterSetId] FOREIGN KEY([DataCollectionParameterSetId]) REFERENCES spc.[DataCollectionParameterSets] ([Id]) ON DELETE NO ACTION
# );
#
# /*
# 2 rows from DataCollectionParameterSets table:
# Id	EquipmentParameterSetDataSource	Code	Description	SampleSize	AllowHoldLot	AllowMove	EnableEditing	ExecutableFilePath	HasChildDataCollectionParameterSet	DataCollectionParameterSetId	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate	IsReading
# 1	1	PPDCPS	Packed Process Data Collection Parameter Set	1	False	True	True		False	NULL	NULL	2025-03-25 21:25:22.359849	NULL	2025-03-25 21:31:01.056147	False
# 2	1	TVS-INS	Inspection	1	False	True	True		False	NULL	NULL	2025-06-24 13:54:16.761599	NULL	2025-06-24 14:24:02.348709	False
# */
#
#
# -- Table: spc.DataCollectionParameterTextLookupValues
# CREATE TABLE spc.[DataCollectionParameterTextLookupValues] (
#     [Id] INTEGER NOT NULL,
#     [DataCollectionParameterId] INTEGER NOT NULL,
#     [Value] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ReferenceValuesCsv] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DataCollectionParameterTextLookupValues] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollectionParameterTextLookupValues_DataCollectionParameters_DataCollectionParameterId] FOREIGN KEY([DataCollectionParameterId]) REFERENCES spc.[DataCollectionParameters] ([Id]) ON DELETE CASCADE
# );
#
# /*
# 2 rows from DataCollectionParameterTextLookupValues table:
# Id	DataCollectionParameterId	Value	ReferenceValuesCsv	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	5	OK	null	NULL	2025-06-21 07:50:53.519195	NULL	NULL
# 2	5	NOT OK	null	NULL	2025-06-21 07:50:53.519275	NULL	NULL
# */
#
#
# -- Table: spc.DataCollections
# CREATE TABLE spc.[DataCollections] (
#     [Id] INTEGER NOT NULL,
#     [Value] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Pattern] NVARCHAR(255) COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Counter] INTEGER NOT NULL,
#     [TransactionDateTime] DATETIME2 NOT NULL,
#     [DataCollectionParameterSetId] INTEGER,
#     [Identifiers] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS",
#     [DataCollectionSource] INTEGER NOT NULL,
#     [CreationLogUserId] INTEGER,
#     [CreationLogDateTime] DATETIME2,
#     [LastUpdateLogUserId] INTEGER,
#     [LastUpdateLogDateTime] DATETIME2,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_DataCollections] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_DataCollections_DataCollectionParameterSets_DataCollectionParameterSetId] FOREIGN KEY([DataCollectionParameterSetId]) REFERENCES spc.[DataCollectionParameterSets] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_DataCollections_Users_CreationLogUserId] FOREIGN KEY([CreationLogUserId]) REFERENCES masterdata.[Users] ([Id]) ON DELETE NO ACTION,
#     CONSTRAINT [FK_DataCollections_Users_LastUpdateLogUserId] FOREIGN KEY([LastUpdateLogUserId]) REFERENCES masterdata.[Users] ([Id]) ON DELETE NO ACTION
# );
#
# /*
# 2 rows from DataCollections table:
# Id	Value	Pattern	Counter	TransactionDateTime	DataCollectionParameterSetId	Identifiers	DataCollectionSource	CreationLogUserId	CreationLogDateTime	LastUpdateLogUserId	LastUpdateLogDateTime	AddedByUserId	AddedDate	UpdatedByUserId	UpdatedDate
# 1	1	{0}	1	2025-03-25 21:32:03.752454	1		2	NULL	NULL	NULL	NULL	NULL	2025-03-25 21:32:03.889630	NULL	2025-03-25 21:32:03.889375
# 2	2	{0}	2	2025-03-25 22:26:28.508115	1		2	NULL	NULL	NULL	NULL	NULL	2025-03-25 22:26:31.485473	NULL	2025-03-25 22:26:31.485399
# */
#
#
# -- Table: spc.SpcTestViolations
# CREATE TABLE spc.[SpcTestViolations] (
#     [Id] INTEGER NOT NULL,
#     [DataCollectionId] INTEGER NOT NULL,
#     [DataCollectionIdentifiers] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [DataCollectionParameterId] INTEGER NOT NULL,
#     [DataCollectionParameterSetId] INTEGER NOT NULL,
#     [ControlChart] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [DataCollectionDateTime] DATETIME2 NOT NULL,
#     [SpcTestName] INTEGER NOT NULL,
#     [Description] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [Value] FLOAT NOT NULL,
#     [Cause] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ActionTaken] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [OcapResult] INTEGER NOT NULL,
#     [EmployeeResponsible] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [VerifiedBy] NVARCHAR COLLATE "SQL_Latin1_General_CP1_CI_AS" NOT NULL,
#     [ActionTakenDateTime] DATETIME2,
#     [AddedByUserId] INTEGER,
#     [AddedDate] DATETIME2,
#     [UpdatedByUserId] INTEGER,
#     [UpdatedDate] DATETIME2,
#     CONSTRAINT [PK_SpcTestViolations] PRIMARY KEY CLUSTERED ([Id]),
#     CONSTRAINT [FK_SpcTestViolations_DataCollectionParameters_DataCollectionParameterId] FOREIGN KEY([DataCollectionParameterId]) REFERENCES spc.[DataCollectionParameters] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_SpcTestViolations_DataCollectionParameterSets_DataCollectionParameterSetId] FOREIGN KEY([DataCollectionParameterSetId]) REFERENCES spc.[DataCollectionParameterSets] ([Id]) ON DELETE CASCADE,
#     CONSTRAINT [FK_SpcTestViolations_DataCollections_DataCollectionId] FOREIGN KEY([DataCollectionId]) REFERENCES spc.[DataCollections] ([Id]) ON DELETE CASCADE
# );
# -- Schema: sys
